# %% [markdown]
# Columns: Home Visitor Closing Over/Under Week Date Year
#
# Overall: the program should return a percent explaining how confident it is that it will be Overall/Under

# %%
import requests
import re
from bs4 import BeautifulSoup
import pandas as pd

# %%
year = 2018# float('nan')
week = 1#float('nan')
url = 'https://www.pro-football-reference.com/years/'+str(year)+'/week_'+str(week)+'.htm'
r = requests.get(url)
soup = BeautifulSoup(r.content, 'html.parser')
soup1 = soup.find_all('div', class_='game_summary expanded nohover')
df = pd.DataFrame([], columns= ["date", "homeTeam", "homeTeamPTS", "awayTeam", 'awayTeamPTS'])
for el in soup1:
    soup2 = el.find_all('table', class_='teams')
    for el2 in soup2:
        soup3 = el2.find_all('td')
        date = str(re.findall('>[A-Z].*<', str(soup3[0]))[0])[1:-1]
        team1 = str(re.findall('>[A-Z][a-z]* [A-Z][a-z]*',str(soup3[1]))[0])[1:]
        team1_points = str(re.findall('>\d+',str(soup3[2]))[0])[1:]
        team2 = str(re.findall('>[A-Z][a-z]* [A-Z][a-z]*',str(soup3[4]))[0])[1:]
        team2_points = str(re.findall('>\d+',str(soup3[5]))[0])[1:]
        temp_series = pd.Series([date,team2,team2_points, team1,team1_points], df.columns)
        df = df.append(temp_series, ignore_index=True)
display(df)
# Out:
#             date             homeTeam homeTeamPTS              awayTeam  \
# 0    Sep 6, 2018  Philadelphia Eagles          18       Atlanta Falcons
# 1    Sep 9, 2018     Cleveland Browns          21   Pittsburgh Steelers
# 2    Sep 9, 2018     Baltimore Ravens          47         Buffalo Bills
# 3    Sep 9, 2018             New York          15  Jacksonville Jaguars
# 4    Sep 9, 2018          New England          27        Houston Texans
# 5    Sep 9, 2018          New Orleans          40             Tampa Bay
# 6    Sep 9, 2018    Minnesota Vikings          24         San Francisco
# 7    Sep 9, 2018       Miami Dolphins          27      Tennessee Titans
# 8    Sep 9, 2018   Indianapolis Colts          23    Cincinnati Bengals
# 9    Sep 9, 2018          Los Angeles          28           Kansas City
# 10   Sep 9, 2018    Carolina Panthers          16        Dallas Cowboys
# 11   Sep 9, 2018       Denver Broncos          27      Seattle Seahawks
# 12   Sep 9, 2018    Arizona Cardinals           6   Washington Redskins
# 13   Sep 9, 2018            Green Bay          24         Chicago Bears
# 14  Sep 10, 2018        Detroit Lions          17              New York
# 15  Sep 10, 2018      Oakland Raiders          13           Los Angeles
#
#    awayTeamPTS
# 0           12
# 1           21
# 2            3
# 3           20
# 4           20
# 5           48
# 6           16
# 7           20
# 8           34
# 9           38
# 10           8
# 11          24
# 12          24
# 13          23
# 14          48
# 15          33
